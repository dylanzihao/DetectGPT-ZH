# %% [markdown]
# # DetectGPT-ZH Pipeline

# %%
# Step 1: Clone the repository
# !git clone https://github.com/dylanzihao/DetectGPT-ZH.git /kaggle/working/DetectGPT-ZH

# %%
# Step 2: Switch to project directory and install dependencies
import os
os.chdir('/kaggle/working/DetectGPT-ZH/src')
# !pip install -r ../requirements.txt

# %%
# Step 3: Run train.py for model training
# !python train.py
